# %% [markdown]
# # Foundations of Spatial Data Science - CASA0013
#
# ## Group Project - Policy Brief (Reproducible Analysis)
# ### Group Name - **Are you gitting me**

# %%
#Importing required packages (within 'sds' docker environment).
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import sklearn.cluster as sklc
import sklearn.metrics as sklm
import os
from urllib.parse import urlparse


from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from matplotlib_scalebar.scalebar import ScaleBar
import palettable.colorbrewer.qualitative as pcq
import palettable.colorbrewer.sequential as pcs
from matplotlib.patches import Patch
from matplotlib.lines import Line2D 
from matplotlib.colors import ListedColormap

# %% [markdown]
# The analysis produced uses the following versions of various libaries:
# |  Library | Version |
# | --- | --- |
# | Geopandas |0.11.1 |
# | Pandas | 1.4.3 |
# | Matplotlib | 3.5.2|
# | Seaborn | 0.11.2 |
# | Sklearn | 1.1.1|
#
# Variations in this may produce different results

# %%
#Installing and importing the venn diagram library
# !pip install matplotlib_venn
from matplotlib_venn import venn3, venn3_circles

# %%
#Defining a function to read in and save remote files in python.
def cache_data(src:str, dest:str) -> str: 
    """
    
    Function to read in and save remote files in python.
    Using the URL and destination as inputs to know where to source the data and where to dump it. 
    
    
    """    
    url = urlparse(src) # We assume that this is some kind of valid URL 
    fn  = os.path.split(url.path)[-1] # Extract the filename
    dfn = os.path.join(dest,fn) # Destination filename
    
    if not os.path.isfile(dfn):
        
        print(f"{dfn} not found, downloading!")

        path = os.path.split(dest)
        
        if len(path) >= 1 and path[0] != '':
            os.makedirs(os.path.join(*path), exist_ok=True)
            
        with open(dfn, "wb") as file:
            response = get(src)
            file.write(response.content)
            
        print("\tDone downloading...")

    else:
        print(f"Found {dfn} locally!")

    return dfn

# %% [markdown]
# ***

# %%
# Reading in LSOA data
lsoa_url = "https://github.com/ZacharyP-E/are-you-gitting-me/blob/main/data/lsoa.gpkg?raw=true"
ddir  = os.path.join('data') # destination directory


lsoa = gpd.read_file(cache_data(lsoa_url, ddir), 
                       columns=['LSOA_CODE', 'LSOA_NAME', 'MSOA_CODE', 'MSOA_NAME', 'STWARDCODE',
                                'STWARDNAME', 'LA_CODE', 'LA_NAME', 'geometry']).set_index('LSOA_NAME')
# Out:
# Found data/lsoa.gpkg locally!

# %%
#Creating a Borough (Local Authoirty) geodataframe from the existing LSOA data
la = lsoa.dissolve(by="LA_NAME")

# %% [markdown]
# ## Hotels Data

# %%
#Reading in the Open Street Map (OSM) data containing pooints of interest across London

lsoa_url = "https://github.com/ZacharyP-E/are-you-gitting-me/blob/main/data/osm.gpkg?raw=true"
ddir  = os.path.join('data') # destination directory


osm = gpd.read_file(cache_data(lsoa_url, ddir), 
                       columns=['osm_id', 'code', 'fclass', 'name', 'geometry']).set_index('osm_id')
# Out:
# Found data/osm.gpkg locally!

# %%
#Filtering the OSM data down to only include hotels
hotel = osm[osm["fclass"] == "hotel"]

# %%
#LSOA is in the British National Grid (BNG) coordinate reference system.
hotel = hotel.to_crs(lsoa.crs)

# %%
#Spatially joining the LSOA to each hotel
lsoa_h = hotel.sjoin(lsoa, predicate="within")

# %%
#Number of hotels by LSOA
lsoa_h["count"] = 1
hotel_count = lsoa_h.groupby("LSOA_CODE")["count"].sum().reset_index()

# %%
#Merging the number of hotels to the LSOA geodataframe
lsoa_hotels = lsoa.merge(hotel_count, on="LSOA_CODE", how= "left")

# %%
#Filling any LSOAs without data to == 0. As any NaNs just mean there were no Hotels present.
lsoa_hotels['count'] = lsoa_hotels['count'].fillna(0)

# %%
#Renaming column of count to be relevant to hotels, useful for joining with furhter data also containing counts.
lsoa_hotels = lsoa_hotels.rename(columns={"count": "hotel_count"})

# %%
#Visualising the count of hotels (raw value, do not consider in analysis as will be biased by area)
fig, ax = plt.subplots(1, figsize=(10,10))

lsoa_hotels.plot(column = "hotel_count", scheme="fisher_jenks", cmap="Blues", ax=ax, legend=True)
la.plot(color="none", edgecolor="black", linewidth=1, ax=ax)

plt.axis("off")

plt.show()

# %% [markdown]
# ## AirBnB Data

# %%
# Reading in AirBnB listings data

airbnb_url = "https://github.com/ZacharyP-E/are-you-gitting-me/blob/main/data/2022-09-10-listings.geofeather?raw=true"
ddir  = os.path.join('data') # destination directory


listings = gpd.read_feather(cache_data(airbnb_url, ddir), 
                       columns=['index', 'geometry', 'id', 'listing_url', 
                                'name', 'description', 'amenities', 'price', 'host_total_listings_count']) #.set_index('id')
# Out:
# Found data/2022-09-10-listings.geofeather locally!

# %%
#LSOA is in the British National Grid (BNG) coordinate reference system.
listings = listings.to_crs(lsoa.crs)

# %%
#Checking for duplicates
cats = ['id', 'listing_url', 'name', 'description']

# listings[cats[2]].value_counts()

# %%
#Creating a new column which identifies if a listings host is casual (1 listing), or professional (>1 listing)
listings['casual_or_prof_flag'] = np.where(listings['host_total_listings_count']>1, 'Professional', 'Casual')

# %%
#Spatially joining the LSOA to each listing
lsoa_ls = listings.sjoin(lsoa, predicate="within")

# %%
#Number of professional vs casual Airbnb hosts by LSOA
lsoa_ls["count"] = 1

professional_count = lsoa_ls.groupby(["LSOA_CODE", "casual_or_prof_flag"])["count"].sum().reset_index()
professional_count
# Out:
#       LSOA_CODE casual_or_prof_flag  count
# 0     E01000001              Casual      4
# 1     E01000001        Professional     10
# 2     E01000002              Casual      4
# 3     E01000002        Professional      4
# 4     E01000003              Casual      6
# ...         ...                 ...    ...
# 7809  E01004763        Professional    328
# 7810  E01004764              Casual     31
# 7811  E01004764        Professional    256
# 7812  E01004765              Casual     15
# 7813  E01004765        Professional    107
#
# [7814 rows x 3 columns]

# %%
# Pivot table to calculate professional rate
dfprofrate = professional_count.pivot(index=['LSOA_CODE'], columns="casual_or_prof_flag", values="count")
dfprofrate.reset_index(inplace=True)

dfprofrate["airbnb_profrate"] = dfprofrate["Professional"] / (dfprofrate["Casual"] + dfprofrate["Professional"]) * 100

dfprofrate.head()
# Out:
# casual_or_prof_flag  LSOA_CODE  Casual  Professional  airbnb_profrate
# 0                    E01000001     4.0          10.0        71.428571
# 1                    E01000002     4.0           4.0        50.000000
# 2                    E01000003     6.0          13.0        68.421053
# 3                    E01000004    47.0         210.0        81.712062
# 4                    E01000005    20.0         100.0        83.333333

# %%
#Number of Airbnb listings by LSOA
airbnb_count = lsoa_ls.groupby("LSOA_CODE")["count"].sum().reset_index()

# %%
#Renaming the count column to be specific to AirBnBs to avoid confusion with further joins
airbnb_count = airbnb_count.rename(columns={"count":"airbnb_count"})

airbnb_count.head()
# Out:
#    LSOA_CODE  airbnb_count
# 0  E01000001            14
# 1  E01000002             8
# 2  E01000003            19
# 3  E01000004           257
# 4  E01000005           120

# %%
#Merging with the larger 'master' dataframe
lsoa_hotels_airbnb = lsoa_hotels.merge(airbnb_count, on="LSOA_CODE", how= "left")

#Merging profrate column 
lsoa_hotels_airbnb = lsoa_hotels_airbnb.merge(dfprofrate, on="LSOA_CODE", how="left")

lsoa_hotels_airbnb.head()
# Out:
#    LSOA_CODE  MSOA_CODE           MSOA_NAME STWARDCODE          STWARDNAME  \
# 0  E01000001  E02000001  City of London 001     00AAFA          Aldersgate
# 1  E01000002  E02000001  City of London 001     00AAFQ         Cripplegate
# 2  E01000003  E02000001  City of London 001     00AAFQ         Cripplegate
# 3  E01000004  E02000001  City of London 001     00AAFT  Farringdon Without
# 4  E01000005  E02000001  City of London 001     00AAFX           Portsoken
#
#   LA_CODE         LA_NAME                                           geometry  \
# 0    00AA  City of London  POLYGON ((532050.879 181817.674, 532021.188 18...
# 1    00AA  City of London  POLYGON ((532267.748 181643.784, 532254.565 18...
# 2    00AA  City of London  POLYGON ((532071.310 182159.597, 532135.127 18...
# 3    00AA  City of London  POLYGON ((531172.252 181124.643, 531133.747 18...
# 4    00AA  City of London  POLYGON ((533378.878 181459.767, 533439.561 18...
#
# ...

# %%
#Filling any NaN values with 0, as it just means there were no AirBnBs present within the LSOA
lsoa_hotels_airbnb['airbnb_count'] = lsoa_hotels_airbnb['airbnb_count'].fillna(0)

# %% [markdown]
# ## Culture data

# %%
# Reading in Culture listings data

culture_url = "https://github.com/ZacharyP-E/are-you-gitting-me/blob/main/data/cultural-infrastructure-map-all-sites.csv?raw=true"
ddir  = os.path.join('data') # destination directory


culture = pd.read_csv(cache_data(culture_url, ddir))
# Out:
# Found data/cultural-infrastructure-map-all-sites.csv locally!

# %%
#Renaming the venue type column for readability
culture = culture.rename(columns = {'Cultural Venue Type':'venue_type'})
culture.shape
# Out:
# (10003, 29)

# %%
#Use site_name, easting and northing to identify unique venues

# HOWEVER, due to geocoding discrepancies, some records that are clearly a single venue have slightly different easting/northing values
# THEREFORE, create a new variable that is 'rough' easting/northing, that is only accurate to ~100m
# USE these new fuzzy e/n variables as the identification field for duplicates along with site name

# Create new easting/northing vars
culture['easting_fuzzy'] = round(culture.easting/100)
culture['northing_fuzzy'] = round(culture.northing/100)

culture.drop_duplicates(subset = ["site_name", "easting_fuzzy", "northing_fuzzy"], keep = 'first', inplace = True, ignore_index = True)
culture.shape
# Out:
# (9444, 31)

# %%
#Convert pandas to geopandas
gdf_culture = gpd.GeoDataFrame(culture, geometry=gpd.points_from_xy(culture.longitude, 
                                                                    culture.latitude, 
                                                                    crs='epsg:4326'))

# Reproject to British National Grid (Existing CRS of the LSOA geodataframe)
gdf_culture = gdf_culture.to_crs(lsoa.crs)

# %%
#Identifying which cultural points are within each LSOA (spatial join)
lsoa_culture = gdf_culture.sjoin(lsoa, predicate="within")

# %%
#Calculating the number of professional vs casual Airbnb hosts by LSOA
lsoa_culture["count"] = 1
culture_count = lsoa_culture.groupby("LSOA_CODE")["count"].sum().reset_index()

# %%
#Renaming the count of cultural points within each LSOA to be specific to avoid confusion when merging with 'master' dataframe
culture_count = culture_count.rename(columns={"count":"culture_count"})

# %%
#Merging with the 'master' data
lsoa_hotels_airbnb_culture = lsoa_hotels_airbnb.merge(culture_count, on="LSOA_CODE", how= "left")

# %%
#Filling in NaN values, as they just equate to LSOAs with no cultural venues. 
lsoa_hotels_airbnb_culture['culture_count'] = lsoa_hotels_airbnb_culture['culture_count'].fillna(0)

# %% [markdown]
# ## Density for each variable

# %% [markdown]
# Density is used to make comparisons across LSOAs possible, as otherwise it is likely that LSOAs with expansive area would bias the results

# %%
#Calculating density per km2 for each variable considered
lsoa_hotels_airbnb_culture['culture_density'] = lsoa_hotels_airbnb_culture["culture_count"] / lsoa_hotels_airbnb_culture.area * 1e6
lsoa_hotels_airbnb_culture['hotel_density'] = lsoa_hotels_airbnb_culture["hotel_count"] / lsoa_hotels_airbnb_culture.area * 1e6
lsoa_hotels_airbnb_culture['airbnb_density'] = lsoa_hotels_airbnb_culture["airbnb_count"] / lsoa_hotels_airbnb_culture.area * 1e6

# %%
#Map of each considered variable
fig, ax = plt.subplots(1,3, figsize=(20,15))

#AirBnB
lsoa_hotels_airbnb_culture.plot(column = "airbnb_density", scheme="fisher_jenks", cmap="Blues", ax=ax[0], legend=True)
la.plot(color="none", edgecolor="black", linewidth=1, ax=ax[0])

ax[0].axis("off")

ax[0].set_title("AirBnB Density")


#Hotel
lsoa_hotels_airbnb_culture.plot(column = "hotel_density", scheme="fisher_jenks", cmap="Reds", ax=ax[1], legend=True)
la.plot(color="none", edgecolor="black", linewidth=1, ax=ax[1])

ax[1].axis("off")

ax[1].set_title("Hotel Density")



#Culture
lsoa_hotels_airbnb_culture.plot(column = "culture_density", scheme="fisher_jenks", cmap="Greens", ax=ax[2], legend=True)
la.plot(color="none", edgecolor="black", linewidth=1, ax=ax[2])

ax[2].axis("off")

ax[2].set_title("Culture Density")


plt.savefig("figures/maps_of_variables.png", dpi=300, facecolor="white", bbox_inches="tight")

plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(8,8))

#AirBnB Prof Rate
lsoa_hotels_airbnb_culture.plot(column = "airbnb_profrate", scheme="fisher_jenks", cmap="Oranges", 
                                ax=ax, 
                                legend=True)
la.plot(color="none", edgecolor="black", linewidth=1,ax=ax)

plt.axis("off")

plt.title("AirBnB Professionalisation Rate")

plt.savefig("figures/map_of_airbnb_profrate.png", dpi=300, facecolor="white", bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Standardisation of data

# %% [markdown]
# Standardising the variables between themselves

# %%
lsoa_hotels_airbnb_culture.columns
# Out:
# Index(['LSOA_CODE', 'MSOA_CODE', 'MSOA_NAME', 'STWARDCODE', 'STWARDNAME',
#        'LA_CODE', 'LA_NAME', 'geometry', 'hotel_count', 'airbnb_count',
#        'Casual', 'Professional', 'airbnb_profrate', 'culture_count',
#        'culture_density', 'hotel_density', 'airbnb_density'],
#       dtype='object')

# %%
#Identifying columns of interest
columns = list(lsoa_hotels_airbnb_culture.columns[-5:].drop(['culture_count', 'airbnb_density']))
columns
# Out:
# ['airbnb_profrate', 'culture_density', 'hotel_density']

# %%
#Applying a MinMaxScaler, allowing easier comparison between variables
mms = MinMaxScaler()
data_standardised = lsoa_hotels_airbnb_culture.copy()
for c in columns:
    data_standardised[c] = mms.fit_transform(lsoa_hotels_airbnb_culture[c].values.reshape(-1,1))

# %%
#Plotting the distribution of the standardised variables.
fig, ax = plt.subplots(1, figsize=(10,10))

sns.histplot(data = data_standardised, x="airbnb_profrate", ax=ax, label="Airbnb", color="b", alpha=0.3)
sns.histplot(data = data_standardised[data_standardised["hotel_density"] > 0], x="hotel_density",  label="Hotel", color="r", alpha=0.3)
sns.histplot(data = data_standardised, x="culture_density", ax=ax, label="Culture", color="g", alpha=0.3)

plt.show()

# %% [markdown]
# ## Clustering

# %%
#Seperating out relevant variable columns
X = data_standardised[columns].fillna(0)

# %%
x = []
y = []

# For resolutions of 'k' in the range 2 to 15
for k in range(2,15):
    #############
    # Do the clustering using the main columns
    kmeans = sklc.KMeans(n_clusters=k, n_init=25, random_state=42).fit(X)
    # Calculate the overall silhouette score
    silhouette_avg = sklm.silhouette_score(X, kmeans.labels_)
    y.append(k)
    x.append(silhouette_avg)
    print('.', end='')
    print()
print(f"Largest silhouette score was {max(x):6.4f} for k={y[x.index(max(x))]}")
plt.plot(y, x)
plt.gca().xaxis.grid(True);
plt.gcf().suptitle("Average Silhouette Scores");
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Largest silhouette score was 0.6868 for k=2

# %% [markdown]
# 5 clusters were selected as the optimum value, based on its proximity to the 'knee'.

# %%
#A random_state is set to allow the kmeans result to be reproducible
random_state_seed = 100
num_clusters = 5 #Identified from the elbow (knee) plot

kmeans_output = sklc.KMeans(n_clusters=num_clusters, random_state=random_state_seed).fit(X)

#Creating a list of the given clustering labels, ready for joining to the lsoa data
clustering_ids_kmeans = kmeans_output.labels_

# %%
#Assigning the cluster id value to the standardised data
data = data_standardised.fillna(0).assign(cluster_id = clustering_ids_kmeans)

# %%
#Mapping the clusters within London
fig, ax = plt.subplots(1, figsize=(10,10))

data.plot(column = "cluster_id", ax=ax, legend=True, k=5)
la.plot(color="none", edgecolor="black", linewidth=1, ax=ax)

plt.axis("off")


# plt.savefig("figures/clusters_map4.png", dpi=300, facecolor="white", bbox_inches="tight")
plt.savefig("figures/clusters_map4_dupsremoved.png", dpi=300, facecolor="white", bbox_inches="tight")
plt.show()

# %% [markdown]
# Creating a table of the median, mean and rank table of the values **grouped** by cluster id, in addition to a heatmap. Allowing identification of what each cluster represents

# %%
#Identifying the median value for each of the variables.
data.groupby("cluster_id")[["hotel_density", "airbnb_profrate","culture_density"]].median()
# Out:
#             hotel_density  airbnb_profrate  culture_density
# cluster_id
# 0                0.000000         0.000000         0.000000
# 1                0.000000         0.605366         0.016271
# 2                0.000000         0.430067         0.009743
# 3                0.061564         0.819785         0.256333
# 4                0.000000         0.785340         0.010001

# %%
#Identifying the mean value for each of the variables.
clusters_data = data.groupby("cluster_id")[["hotel_density", "airbnb_profrate","culture_density"]].mean()
clusters_data
# Out:
#             hotel_density  airbnb_profrate  culture_density
# cluster_id
# 0                0.000234         0.012288         0.006743
# 1                0.003028         0.605463         0.033746
# 2                0.002387         0.396333         0.024144
# 3                0.178496         0.804546         0.288222
# 4                0.007559         0.800111         0.024844

# %%
#Using visualisaiton to identify the clusters characteristics
sns.heatmap(clusters_data)
# Out:
# <AxesSubplot:ylabel='cluster_id'>

# %%
#Using rank to identiy the clusters characteristics
clusters_data.rank()
# Out:
#             hotel_density  airbnb_profrate  culture_density
# cluster_id
# 0                     1.0              1.0              1.0
# 1                     3.0              3.0              4.0
# 2                     2.0              2.0              2.0
# 3                     5.0              5.0              5.0
# 4                     4.0              4.0              3.0

# %% [markdown]
# Table for 5 clusters
#
#
#
#
# |  Cluster ID| Description (Hotel, AirBnB, Culture) |
# | --- | --- |
# | 0 |Low - Low - Low |
# | 1 | Mid - Mid - High |
# | 2 | Low - Low - Low|
# | 3 | High - High - High |
# | 4 | High - High - Mid|

# %%
#Identifying the silhouette score for the clustering model put to use
silhouette_kmeans = sklm.silhouette_score(X,clustering_ids_kmeans)


print("Silhouette Score:", silhouette_kmeans)
# Out:
# Silhouette Score: 0.6085932083957518

# %% [markdown]
# ### Mapping Clustering IDs

# %%
#Identifying the extent of the study area
tbounds = list(la.total_bounds)

# %%
#Identifying how much around the edge of each figure should be added
extra_bound = 0.1
x1, y1 = 500, 500

# %%
#Inisalising the plots with specific size (inches)
fig, ax = plt.subplots(figsize=(15, 20))

#Main plot
data.plot(column = "cluster_id", ax=ax, legend=True, k=5, scheme="fisher_jenks", edgecolor="white", linewidth=0.05,
             cmap = ListedColormap(["#377eb8", "#4daf4a", "#ff7f00", "#984ea3", "#e41a1c"]))

la.plot(ax=ax, color="none", edgecolor="black", linewidth=1, alpha=0.4)

#Setting main plot x and y limits
plt.xlim(tbounds[0]-extra_bound , tbounds[2] +extra_bound)
plt.ylim(tbounds[1] -extra_bound, tbounds[3]+extra_bound)

ax.add_artist(ScaleBar(1, box_color='none', location="lower left", border_pad=1))

legend_e = [Patch(facecolor= "#377eb8", # blue
                  edgecolor="white", label="Low Hotels, Low AirBnB, Low Culture"),
            Patch(facecolor= "#4daf4a", # green"#e41a1c", # red
                  edgecolor="white", label="Medium Hotels, Medium AirBnB, High Culture"),
            Patch(facecolor= "#ff7f00", # orange
                  edgecolor="white", label="Low Hotels, Low AirBnB, Low Culture"),
            Patch(facecolor= "#984ea3", # purple
                  edgecolor="white", label="High Hotels, High AirBnB, High Culture"),
            Patch(facecolor= "#e41a1c", # red
                  edgecolor="white", label="High Hotels, High AirBnB, Medium Culture"),
            Line2D([0], [0], color="black", lw=2, linestyle="-", label="Borough Boundary")]

plt.legend(handles=legend_e, loc= (0.10, -0.13), title="Key (LSOA Classification)", title_fontsize="large", ncol=2)


# #Starting the zoomed axis for Central London
# axinsC = zoomed_inset_axes(ax, 2, loc=4, bbox_to_anchor=(3100, 850))

# #Establishing the x and y limits for the zoomed plot
# minxC, minyC, maxxC, maxyC =  528000, 179000, 532000, 182000
# axinsC.set_xlim(minxC - x1, maxxC + x1)
# axinsC.set_ylim(minyC - y1, maxyC + y1)

# #Setting the box on the main plot to then zoom to the zoomed plot
# mark_inset(ax, axinsC, loc1=1, loc2=3, fc="none", ec="0.5")

# #Scale bar for zoom plot
# axinsC.add_artist(ScaleBar(1, box_color='none', location="lower right", border_pad=1))

# # Plot zoom window
# data.plot(column = "cluster_id", ax=axinsC, legend=False, k=5,
#              scheme="fisher_jenks", edgecolor="white", linewidth=0.05,
#              cmap = ListedColormap(["#377eb8", "#4daf4a", "#ff7f00", "#984ea3", "#e41a1c"]))

# la.plot(ax=axinsC, color="none", edgecolor="black", linewidth=1, alpha=0.4)


# plt.setp(axinsC.get_xticklabels(), visible=False)
# plt.setp(axinsC.get_yticklabels(), visible=False)

# ax.set_axis_off()
# axinsC.set_yticks([])
# axinsC.set_xticks([])





# #Starting the zoomed axis for Croydon London
# axinsCr = zoomed_inset_axes(ax, 3, loc=4, bbox_to_anchor=(500, 2850))

# #Establishing the x and y limits for the zoomed plot
# minxCr, minyCr, maxxCr, maxyCr =  list(data[(data["LA_NAME"] == "Croydon") & (data["cluster_id"] == 4) & (data["STWARDNAME"] == "Fairfield")].total_bounds)
# axinsCr.set_xlim(minxCr - x1, maxxCr + x1)
# axinsCr.set_ylim(minyCr - y1, maxyCr + y1)

# #Setting the box on the main plot to then zoom to the zoomed plot
# mark_inset(ax, axinsCr, loc1=1, loc2=3, fc="none", ec="0.5")

# #Scale bar for zoom plot
# axinsCr.add_artist(ScaleBar(1, box_color='none', location="lower right", border_pad=1))

# # Plot zoom window
# data.plot(column = "cluster_id", ax=axinsCr, legend=False, k=5,
#              scheme="fisher_jenks", edgecolor="white", linewidth=0.05,
#              cmap = ListedColormap(["#377eb8", "#4daf4a", "#ff7f00", "#984ea3", "#e41a1c"]))

# la.plot(ax=axinsCr, color="none", edgecolor="black", linewidth=1, alpha=0.4)


# plt.setp(axinsCr.get_xticklabels(), visible=False)
# plt.setp(axinsCr.get_yticklabels(), visible=False)

# ax.set_axis_off()
# axinsCr.set_yticks([])
# axinsCr.set_xticks([])




# plt.savefig("figures/5cluster_map(with inset).png", dpi=200, facecolor="white", bbox_inches="tight")
plt.savefig("figures/5cluster_map(with inset)_dupsremoved_airbnbprofrate.png", dpi=200, facecolor="white", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Venn Diagram for brief
# Creating a venn diagram to help conceptualise the theory behind the clustering model

# %%
v = venn3(subsets = (5, 5, 0.3, 5, 0.3, 0.3, 0.6), set_labels = ('Hotel', 'Culture', 'AirBnB'), alpha=0.7);

v.get_patch_by_id('111').set_color('Purple') #Middle Intersection
v.get_patch_by_id('100').set_color('blue') #Hotel
v.get_patch_by_id('110').set_color('Green') #Hotel and Culture
v.get_patch_by_id('010').set_color('blue') #Culture
v.get_patch_by_id('011').set_color('orange') #AirBnB and Culture
v.get_patch_by_id('001').set_color('blue') #AirBnB
v.get_patch_by_id('101').set_color('red') #Hotel and AirBnB


for text in v.subset_labels:
    text.set_fontsize(0)

plt.savefig("figures/venn_brief.png", dpi=200, facecolor="white", bbox_inches="tight")

    
plt.show()

# %%
out = venn3(subsets = (5, 5, 0.3, 5, 0.3, 0.3, 0.6), set_labels=('Hotel', 'Culture', 'AirBnB'), set_colors=('orange', 'blue', 'green'))


v.get_patch_by_id('111').set_color('red')

    
#plt.savefig("figures/venn_brief.png", dpi=200, facecolor="white", bbox_inches="tight")

plt.show()
